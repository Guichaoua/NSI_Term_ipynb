# %% [markdown]
# ## AFVM1 :  Pile
# 1. Définir une classe `Pile`, qui permette d’instancier des objets tels que `pile1`, `pile2`, etc.
#
# Le constructeur de cette classe initialisera un attribut d’instance `contenu`.
#
# D'autres méthodes seront définies :
# * `estVide` permettra de savoir si la pile  est vide
# * `empiler(elt)` permettra d'empiler un nouvel élément elt sur la pile
# * `depiler` permettra de dépiler, c’est-à-dire récupérer l'élément au sommet de la pile tout en le supprimant ;
# * `copier(p)` permettra de créer une nouvelle pile avec le même contenu qua la pile `p`
# * `__str__` permettra de  permet d'afficher la pile directement avec la fonction `print()` (cette méthode ne modifiera pas l'état de la pile).

# %% [markdown]
# 2.  Tester votre classe en reproduisant la chronologie ci dessous:
# ![piles.png](attachment:piles.png)

# %% [markdown]
# 3. Faire une fonction `positive(p)` qui crée une pile avec les élements positifs de la pile `p`, dans le même ordre que `p`.

# %% [markdown]
# ### AFVM2 : File
#
# 1. On considère la file `F = ("Mystique","Rogue","Moonstar","Sprite")` avec `"Mystique"` en début de `F`.
#
# Décrire la file `F` après exécution des instructions suivantes :
#
#         e = defiler(F)
#         enfiler(F,"Nightcrawler")
#         defiler(F)
#         enfiler(F,e)
#         defiler(F)

# %% [markdown]
# 2. On souhaite implémenter une file, en utilisant 2 piles :
#     ![Capture%20d%E2%80%99e%CC%81cran%202021-10-18%20a%CC%80%2021.13.12.png](attachment:Capture%20d%E2%80%99e%CC%81cran%202021-10-18%20a%CC%80%2021.13.12.png)
#
#     Reprendre la question 1 avec cette nouvelle implémentation.

# %% [markdown]
# 3. Écrire une classe `FilePP` dont les deux attributs sont des instances d’une classe `Pile`.<br>
# 4. Définir une méthode `estVide`.<br>
# Une file est vide lorsque ces deux piles sont toutes deux vides.
# 5. Définir une méthode `enfiler` qui ajoute un élément dans la file.<br>
# Cela se traduit par le placement de l’élément dans la première pile.<br>
#
# 6. Définir une méthode `defiler` qui retire un élément de la file.<br>
# Cela se traduit par le retrait d’un élément de la deuxième pile si elle n’est pas vide. Sinon on dépile
# tous les éléments de la première pile, que l’on empile sur la deuxième , avant de retirer un élément de
# la deuxième pile.
#
# 7. Définir une méthode `__str__` qui permet d'afficher la file directement avec la fonction `print()` (cette méthode ne modifiera pas l'état de la file).

# %% [markdown]
# 8. On considère la file `F = ("Mystique","Rogue","Moonstar","Sprite")` avec `"Mystique"` en début de `F`.
# La créer avec la classe `FilePP` et l'afficher.

# %% [markdown]
# 9. Réecrire le code ci dessous avec les méthodes de la classe `FilePP` et afficher la file `F` après exécution de chaques instructions.
#
#         F = ("Mystique","Rogue","Moonstar","Sprite")
#         e = defiler(F)
#         enfiler(F,"Nightcrawler")
#         defiler(F)
#         enfiler(F,e)
#         defiler(F)
