# %% [markdown]
# # A- Fiche 8 - Arbre Binaire de Recherche

# %% [markdown]
# ### AFVM1 :
# 1. Pour chacune des questions suivantes, dessiner l'arbre binaire de recherche a de la classe `Abr` après l'exécution de la séquence d'instructions proposée :<BR>
# (a)<BR>
# ``
# a = Abr()
#  a.ajout(5)
#  a.ajout(7)
#  a.ajout(4)
#  a.ajout(6)
#  a.ajout(3)
# ``
#
# (b) <BR>
# `lst = [1,2,3,4,5]
#  a = Abr()
#  for e in lst :
#    a.ajout(e)`

# %% [markdown]
# 2. Compléter les codes des méthodes `ajout` et `recherche`.

# %%
class Noeud:
    def __init__(self,v,fg,fd): 
        self.valeur = v 
        self.fils_gauche = fg 
        self.fils_droit = fd

class Abr:
    """arbres binaires de recherche """
    def __init__(self, noeud = None): 
        self.racine = noeud
        
    def est_vide(self):
        return self.racine is None
    
    def val(self):
        assert not self.est_vide() 
        return self.racine.valeur
    
    def fg(self):
        assert not self.est_vide() 
        return self.racine.fils_gauche
    
    def fd(self):
        assert not self.est_vide() 
        return self.racine.fils_droit
    
    def ajout(self, e):
        """ a.ajout(e) ajoute un élément e dans l'Abr a """
        if self.est_vide(): 
            self.racine = Noeud(...
        elif e < self.val(): 
            ...
        else: 
            ...
                                
    def recherche(self, e):
        """ a.recherche(e) renvoie True si e est dans l'Abr a et False sinon """
        if self.est_vide(): 
            return ...
        elif e == self.val(): 
            return ...
        elif e < self.val(): 
            return ...
        else:
            return ...

# %% [markdown]
# ### AFVM2 :
# Créer l'arbre binaire suivant :
# ![graphe5.png](attachment:graphe5.png)

# %% [markdown]
# ### AFVM3 :
# 1. Dans un ABR, où peut-on trouver le plus petit élément ?
# 2. Écrire une fonction `minimum(a)` qui prend en argument un ABR `a` de la classe `Abr` et qui renvoie le minimum des valeurs de ses noeuds ; si l'arbre est vide, la fonction renvoie `None`.

# %% [markdown]
# ### AFVM4 :
# Quel parcours  permet de parcourir les noeuuds d'un ABR selon l'ordre croissant de ses éléments ?
# Écrire une fonction `valeurs_croissantes(a)` qui prend en argument un ABR `a` de la classe `Abr` et qui affiche les valeurs de ses noeuds selon l'ordre croissant.

# %% [markdown]
# ### AFVM5 :
# 1. Cas de doublons :
# Dessiner l'ABR `a` de la classe `Abr` obtenu après l'exécution des instructions suivantes :
#
# `lst = [3,4,1,2,1,3,2,4]
#  a = Abr()
#  for e in lst:
#     a.ajout(e)`
# 2. Écrire une fonction `compte(a,e)` qui prend en argument un ABR `a` de la classe `Abr`, un élément `e` et qui renvoie le nombre d'occurrence de `e` dans `a`. On supposera que `a` a été construit avec la méthode `ajout` et on prendra soin de ne pas descendre dans les sous-arbres dans lesquels il est certain que `e` ne se trouve pas.

# %% [markdown]
# ### AFVM6 : Un algorithme de tri :
# 1. Écrire une fonction `empiler(a,p)` qui prend en argument un ABR `a` de la classe `Abr` et une pile `p`, et qui empile un à un les éléments de `a` dans `p` en les parcourant dans l'ordre infixe. On utilisera les listes Python pour modéliser les piles avec les méthodes `append` et `pop`.
#
#
# 2. Écrire une fonction `tri(p)` qui prend en argument une pile `p`, qui dépile tous ses éléments un à un en les ajoutant dans un ABR. La fonction `tri(p)` utilise ensuite l'instruction `empiler(a,p)` pour trier `p` selon l'ordre croissant.

# %% [markdown]
# ### AFVM7 :  *
# 1. Écrire une fonction `supprimer_min(a)` qui prend en argument un ABR de la classe `Abr` et qui supprime une occurrence de son minimum.
#
#
# 2. Écrire une fonction `supprimer(a,e)` qui supprime une occurrence de l'élément `e` dans l'ABR `a` de la classe `Abr` (on utilisera la fonction minimum du AFVM3 et la fonction `supprimer_min` de la question précédente).
